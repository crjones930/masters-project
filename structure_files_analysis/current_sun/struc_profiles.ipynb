# %%
import matplotlib.pyplot as plt
import numpy as np
import glob
import pandas as pd

# %%
PATTERN= "/z2/users/cj517/lscaledir_3D/r_min0.4_r_max0.9_from2d_v0_Om0/struc*"
all_files = sorted(glob.glob(PATTERN))
all_files
# Out:
# ['/z2/users/cj517/lscaledir_3D/r_min0.4_r_max0.9_from2d_v0_Om0/struc.cont000002000',
#  '/z2/users/cj517/lscaledir_3D/r_min0.4_r_max0.9_from2d_v0_Om0/struc.cont000002001',
#  '/z2/users/cj517/lscaledir_3D/r_min0.4_r_max0.9_from2d_v0_Om0/struc.cont000002002',
#  '/z2/users/cj517/lscaledir_3D/r_min0.4_r_max0.9_from2d_v0_Om0/struc.cont000002003',
#  '/z2/users/cj517/lscaledir_3D/r_min0.4_r_max0.9_from2d_v0_Om0/struc.cont000002004',
#  '/z2/users/cj517/lscaledir_3D/r_min0.4_r_max0.9_from2d_v0_Om0/struc.cont000002005',
#  '/z2/users/cj517/lscaledir_3D/r_min0.4_r_max0.9_from2d_v0_Om0/struc.cont000002006',
#  '/z2/users/cj517/lscaledir_3D/r_min0.4_r_max0.9_from2d_v0_Om0/struc.cont000002007',
#  '/z2/users/cj517/lscaledir_3D/r_min0.4_r_max0.9_from2d_v0_Om0/struc.cont000002008',
#  '/z2/users/cj517/lscaledir_3D/r_min0.4_r_max0.9_from2d_v0_Om0/struc.cont000002009',
#  '/z2/users/cj517/lscaledir_3D/r_min0.4_r_max0.9_from2d_v0_Om0/struc.cont000002010',
# ...

# %%
spec_file = all_files[0]

# %%
with open(spec_file, "r") as f:
    f.readline()
    f.readline()
    print(f.readline())
# Out:
# index                            radius                           vel_rms                          crossing_time_vel                crossing_time_hp                 press_height                     e_int_spec                       nabla                            nabla_adiab                      pressure                         temperature                      entropy                          entropy_calc                     e_kin                            shell_mass                       density                          flux_enthalpy                    flux_e_kin                       flux_rad                         flux_diff_scalar                 vel_1_rms                        vel_2_rms                        vel_3_rms                        vel_1                            vel_2                            vel_3                            theta_1                          u_phi_average_1                  theta_2                          u_phi_average_2                  theta_3 
# ...

# %%
top_headers = ['time', 'e_kin_tot', 'temp_tot', 'convective_time_hp', 'convective_time_vel_rms', 'convective_time_vel_1_rms', 'convective_time_hp_vel_rms']
time, e_kin_tot, temp_tot, convective_time_hp, convective_time_vel_rms, convective_time_vel_1_rms, convective_time_hp_vel_rms = [1.999982E+07, 9.576E+38, 2.714E+06, 1.274E+06, 2.445E+06, 6.477E+06, 3.251E+06]
headers = ['index', 'radius', 'vel_rms', 'crossing_time_vel', 'crossing_time_hp', 'press_height', 'e_int_spec', 'nabla', 'nabla_adiab', 'pressure', 'temperature', 'entropy', 'entropy_calc', 'e_kin', 'shell_mass', 'density', 'flux_enthalpy', 'flux_e_kin', 'flux_rad', 'flux_diff_scalar', 'vel_1_rms', 'vel_2_rms', 'vel_3_rms', 'vel_1', 'vel_2', 'vel_3', 'theta_1', 'u_phi_average_1', 'theta_2', 'u_phi_average_2', 'theta_3', 'u_phi_average_3', 'theta_4', 'u_phi_average_4', 'theta_5', 'u_phi_average_5', 'theta_6', 'u_phi_average_6', 'theta_7', 'u_phi_average_7', 'theta_8', 'u_phi_average_8', 'theta_9', 'u_phi_average_9', 'theta_10', 'u_phi_average_10', 'theta_11', 'u_phi_average_11', 'angular_momentum', 'scalar', 'flux_mass', 'nabla_mu_equiv', 'flux_heat_instant', 'flux_heat_init', 'flux_heat_ref_prof', 'flux_heat_ref_field', 'brunt_vaissala', 'temperature_std', 'temperature_skew', 'temperature_kurt', 'temperature_rms', 'density_std', 'density_skew', 'density_kurt', 'density_rms', 'temperature_fluct', 'temperature_up_fluct', 'temperature_down_fluct', 'vel_1_correlation', 'buoyancy_work', 'vel_1_std', 'vel_1_skew', 'vel_1_kurt', 'vel_1_rms', 'temperature_gradient', 'thermal_conductivity', 'strain_dev_1_1_squared', 'strain_dev_2_2_squared', 'strain_dev_3_3_squared', 'strain_dev_1_2_squared', 'strain_dev_1_3_squared', 'strain_dev_2_3_squared']

# %%
r_tot = 70774597466.3827
r_bot = 0.4 * r_tot
r_top = 0.9 * r_tot
Nr = 570
Ntheta = 360
Nphi = 720
dr_grid = (r_top - r_bot) / Nr
r_env_init = 5.149819426617924E+10

# %%
df = pd.DataFrame(np.genfromtxt(spec_file,skip_header=3),columns=headers)
df = df.set_index('index')
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.DataFrame(np.genfromtxt(spec_file,skip_header=3),columns=headers)
#       2 df = df.set_index('index', dtype='int')
#       3 df
#
# NameError: name 'pd' is not defined

# %%
df.keys()
# Out:
# Index(['radius', 'vel_rms', 'crossing_time_vel', 'crossing_time_hp',
#        'press_height', 'e_int_spec', 'nabla', 'nabla_adiab', 'pressure',
#        'temperature', 'entropy', 'entropy_calc', 'e_kin', 'shell_mass',
#        'density', 'flux_enthalpy', 'flux_e_kin', 'flux_rad',
#        'flux_diff_scalar', 'vel_1_rms', 'vel_2_rms', 'vel_3_rms', 'vel_1',
#        'vel_2', 'vel_3', 'theta_1', 'u_phi_average_1', 'theta_2',
#        'u_phi_average_2', 'theta_3', 'u_phi_average_3', 'theta_4',
#        'u_phi_average_4', 'theta_5', 'u_phi_average_5', 'theta_6',
#        'u_phi_average_6', 'theta_7', 'u_phi_average_7', 'theta_8',
#        'u_phi_average_8', 'theta_9', 'u_phi_average_9', 'theta_10',
#        'u_phi_average_10', 'theta_11', 'u_phi_average_11', 'angular_momentum',
#        'scalar', 'flux_mass', 'nabla_mu_equiv', 'flux_heat_instant',
#        'flux_heat_init', 'flux_heat_ref_prof', 'flux_heat_ref_field',
#        'brunt_vaissala', 'temperature_std', 'temperature_skew',
# ...

# %%
plt.plot(df['radius']/r_tot,df['flux_e_kin'])
plt.axvline(r_env_init/r_tot)

# %%
df['vel_1_rms'].plot()
# Out:
# <Axes: xlabel='index'>

# %%
k = df['radius']/r_tot
k.shape
vel_1_rms = df['vel_1_rms'].values.T[0]

# %%
fig, ax = plt.subplots()
ax.set_xlim(r_env_init / r_tot - 0.01, r_env_init / r_tot + 0.01)
ax.set_ylim(-1,1)
# ax.plot(df['radius']/r_tot,df['nabla'])
# ax.plot(df['radius']/r_tot,df['nabla_adiab'])
# ax.plot(df['radius']/r_tot,df['nabla'] - df['nabla_adiab'])
ax.scatter(df['radius']/r_tot,df['flux_e_kin']/2.5E7)
ax.plot(df['radius']/r_tot,df['flux_e_kin']/2.5E7)
ax.axvline(r_env_init / r_tot, linestyle='--', color='k', label='Schw_1D')

ax.axvline(51303170466.0108 / r_tot, linestyle='--', color='r', label='first zero')
ax.grid()
ax.legend()

# %%
r_tot*0.05
# Out:
# 3538729873.3191357

# %%
df['radius'][329]
# Out:
# np.float64(51374774768.0)

# %%
df['super_adiab'] = df['nabla'] - df['nabla_adiab']

# %%
fig, ax = plt.subplots()
# ax.set_xlim(r_env_init / r_tot - 0.01, r_env_init / r_tot + 0.01)
ax.set_ylim(-1,1)
# ax.plot(df['radius']/r_tot,df['nabla'])
# ax.plot(df['radius']/r_tot,df['nabla_adiab'])
# ax.plot(df['radius']/r_tot,df['nabla'] - df['nabla_adiab'])
# ax.scatter(df['radius']/r_tot,vel_1_rms)
ax.plot(df['radius']/r_tot,0.9*vel_1_rms/vel_1_rms.max(),c='k')
ax.plot(df['radius']/r_tot,0.9 * df['flux_enthalpy']/abs(df['flux_enthalpy']).max(),c='cyan')
ax.plot(df['radius']/r_tot,0.9 * df['flux_rad']/abs(df['flux_rad']).max(),c='r')
ax.plot(df['radius']/r_tot,0.9 * df['super_adiab']/abs(df['super_adiab']).max(),c='b')
ax.axvline(r_env_init / r_tot, linestyle='--', color='k', label='Schw_1D')

# ax.axvline(51303170466.0108 / r_tot, linestyle='--', color='r', label='first zero')
ax.grid()
ax.legend()

# %%
def read_file(fname):
    with open(fname, 'r') as f:
        t = float(f.readline())
        df = pd.read_csv(f, sep='\s+',
                    #names=["num_theta", "theta_deg", "HP1", "r1", "renv", "HP2", "r21", "rcore"])
        #names=["num_theta", "theta_deg", "HP1", "r1", "renv", "HP2", "r21", "rcore", "renvdown", "renvup", "rcoredown", "rcoreup"])
        names=["num_phi", "phi_deg", "num_theta", "theta_deg", "HP1", "r1", "r2","r3","r4","r5", "HP2", "r21", "r22","r23","r24","r25"])
        df["time"] = t
        return df
# r21=zerok (Kin. flux)  
# r22=zeroc (heat flux fluxcr using horizontal average T(i,t))     r23=zeroc1 (heat flux fluxcr1  usint T init)
# r24=zeroc2  (heat flux fluxcr2 using time/horizontal average <T(i)>=avtar(i))  
# r25=zeroc3 (heat flux fluxcr3 using time average of T(i,j) <T(i,j)>=avt(i,j))

# %%
PATTERN= "/z2/users/cj517/lscaledir_3D/r_min0.4_r_max0.9_from2d_v0_Om0/zerodir/*2000*"
spec_files = sorted(glob.glob(PATTERN))
df_zeros = pd.DataFrame(read_file(spec_files[0]))
df_zeros.set_index('num_theta').sort_index()
# Out:
#            num_phi  phi_deg  theta_deg           HP1            r1  \
# num_theta
# 1              710    236.5       30.2  5.615973e+09  5.144499e+10
# 1               38     12.5       30.2  5.615998e+09  5.130456e+10
# 1               37     12.2       30.2  5.615999e+09  5.130456e+10
# 1              708    235.8       30.2  5.615977e+09  5.137477e+10
# 1              275     91.5       30.2  5.615995e+09  5.130456e+10
# ...            ...      ...        ...           ...           ...
# 360            355    118.2      149.8  5.615981e+09  5.130456e+10
# 360            716    238.5      149.8  5.615963e+09  5.116414e+10
# 360            350    116.5      149.8  5.615986e+09  5.123435e+10
# 360            352    117.2      149.8  5.615984e+09  5.116414e+10
# 360            351    116.8      149.8  5.615985e+09  5.116414e+10
#
#                      r2            r3            r4            r5  HP2  \
# num_theta
# ...

# %%
df_zeros['depth'] = - (df_zeros["r1"] - r_env_init)
simple_mean_zero_kin = r_env_init - df_zeros['depth'].mean()
max_zero_kin = r_env_init - df_zeros['depth'].max()
simple_mean_zero_kin / r_tot, max_zero_kin / r_tot
# Out:
# (np.float64(0.7248811339461075), np.float64(0.714980117322966))

# %%
df_zeros['depth'] = - (df_zeros["r2"] - r_env_init)
simple_mean_zero_enth = r_env_init - df_zeros['depth'].mean()
max_zero_enth = r_env_init - df_zeros['depth'].max()
simple_mean_zero_enth / r_tot, max_zero_enth / r_tot
# Out:
# (np.float64(0.7257653474953886), np.float64(0.7100198630429364))

# %%
fig, ax = plt.subplots()
ax.set_xlim(0.7, 0.76)
ax.set_ylim(-2,1)
# ax.plot(df['radius']/r_tot,df['nabla'])
# ax.plot(df['radius']/r_tot,df['nabla_adiab'])
# ax.plot(df['radius']/r_tot,df['nabla'] - df['nabla_adiab'])
# ax.scatter(df['radius']/r_tot,vel_1_rms)
ax.plot(df['radius']/r_tot,df['super_adiab']/0.0005,c='tab:brown')
ax.plot(df['radius']/r_tot,df['flux_enthalpy']/1E10,c='tab:red')
ax.plot(df['radius']/r_tot,df['flux_e_kin']/5E7,c='tab:blue')
ax.axvline(r_env_init / r_tot, color='k', label='Schw_1D',linewidth=2)

ax.axvline(simple_mean_zero_kin / r_tot, color='tab:blue', label='Kinetic mean depth',linewidth=2)
ax.axvline(max_zero_kin / r_tot, color='tab:blue', label='Kinetic max depth',linestyle='--',linewidth=2)

ax.axvline(simple_mean_zero_enth / r_tot, color='tab:red', label='Enthalpy mean depth',linewidth=2)
ax.axvline(max_zero_enth / r_tot, color='tab:red', label='Enthalpy max depth',linestyle='--',linewidth=2)

# ax.axvline(51303170466.0108 / r_tot, linestyle='--', color='r', label='first zero')
ax.grid()
ax.legend()
plt.title('Om0 Checkpoint 2000')
# Out:
# Text(0.5, 1.0, 'Om0 Checkpoint 2000')

# %%
PATTERN= "/z2/users/cj517/lscaledir_3D/r_min0.4_r_max0.9_from2d_v0_Om0/struc*"
all_files = sorted(glob.glob(PATTERN))

# %%
f1 = all_files[0]
f2 = all_files[330]
f3 = all_files[-1]

# %%
f1_name = f1[-4:]
f2_name = f2[-4:]
f3_name = f3[-4:]

# %%
df1 = pd.DataFrame(np.genfromtxt(f1,skip_header=3),columns=headers)
df1 = df1.set_index('index')
df2 = pd.DataFrame(np.genfromtxt(f2,skip_header=3),columns=headers)
df2 = df2.set_index('index')
df3 = pd.DataFrame(np.genfromtxt(f3,skip_header=3),columns=headers)
df3 = df3.set_index('index')

# %%
df1['super_adiab'] = df1['nabla'] - df1['nabla_adiab']
df2['super_adiab'] = df2['nabla'] - df2['nabla_adiab']
df3['super_adiab'] = df3['nabla'] - df3['nabla_adiab']

# %%
# PATTERN= "/z2/users/cj517/lscaledir_3D/r_min0.4_r_max0.9_from2d_v0_Om0/zerodir/*" + f1_name + "*"
# f1_zero = sorted(glob.glob(PATTERN))
# df_zeros = pd.DataFrame(read_file(f1_zero[0]))
# df_zeros.set_index('num_theta').sort_index()

# %%
fig, ax = plt.subplots()
ax.set_xlim(0.7, 0.76)
ax.set_ylim(-2,1)
# ax.plot(df['radius']/r_tot,df['nabla'])
# ax.plot(df['radius']/r_tot,df['nabla_adiab'])
# ax.plot(df['radius']/r_tot,df['nabla'] - df['nabla_adiab'])
# ax.scatter(df['radius']/r_tot,vel_1_rms)
ax.plot(df1['radius']/r_tot,df1['super_adiab']/0.0005,c='tab:brown')
ax.plot(df1['radius']/r_tot,df1['flux_enthalpy']/1E10,c='tab:red')
ax.plot(df1['radius']/r_tot,df1['flux_e_kin']/5E7,c='tab:blue')

# ax.plot(df2['radius']/r_tot,df2['super_adiab']/0.0005,c='tab:brown', linestyle='--')
# ax.plot(df2['radius']/r_tot,df2['flux_enthalpy']/1E10,c='tab:red', linestyle='--')
# ax.plot(df2['radius']/r_tot,df2['flux_e_kin']/5E7,c='tab:blue', linestyle='--')

# ax.plot(df3['radius']/r_tot,df3['super_adiab']/0.0005,c='tab:brown', linestyle=':')
# ax.plot(df3['radius']/r_tot,df3['flux_enthalpy']/1E10,c='tab:red', linestyle=':')
# ax.plot(df3['radius']/r_tot,df3['flux_e_kin']/5E7,c='tab:blue', linestyle=':')

ax.axvline(r_env_init / r_tot, color='k', label='Schw_1D',linewidth=2)

# ax.axvline(simple_mean_zero_kin / r_tot, color='tab:blue', label='Kinetic mean depth',linewidth=2)
# ax.axvline(max_zero_kin / r_tot, color='tab:blue', label='Kinetic max depth',linestyle='--',linewidth=2)

# ax.axvline(simple_mean_zero_enth / r_tot, color='tab:red', label='Enthalpy mean depth',linewidth=2)
# ax.axvline(max_zero_enth / r_tot, color='tab:red', label='Enthalpy max depth',linestyle='--',linewidth=2)

# ax.axvline(51303170466.0108 / r_tot, linestyle='--', color='r', label='first zero')
ax.grid()
ax.legend()
plt.title('Om0 Checkpoint 2000')
# Out:
# Text(0.5, 1.0, 'Om0 Checkpoint 2000')

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3, sharex=True)
ax1.set_xlim(0.7, 0.76)
ax1.set_ylim(-2,1)
ax2.set_xlim(0.7, 0.76)
ax2.set_ylim(-2,1)
ax3.set_xlim(0.7, 0.76)
ax3.set_ylim(-2,1)

ax1.axhline(0, color='k',linewidth=1)
ax2.axhline(0, color='k',linewidth=1)
ax3.axhline(0, color='k',linewidth=1)

ax1.axvline(r_env_init / r_tot, color='k', label='Schw_1D',linewidth=2)
ax2.axvline(r_env_init / r_tot, color='k', label='Schw_1D',linewidth=2)
ax3.axvline(r_env_init / r_tot, color='k', label='Schw_1D',linewidth=2)


vel_1_rms = df1['vel_1_rms'].values.T[0]

ax1.plot(df1['radius']/r_tot,df1['super_adiab']/0.0005,c='tab:brown')
ax1.plot(df1['radius']/r_tot,df1['flux_enthalpy']/1E10,c='tab:red')
ax1.plot(df1['radius']/r_tot,df1['flux_e_kin']/5E7,c='tab:blue')
ax1.plot(df1['radius']/r_tot,vel_1_rms/1E3,c='tab:olive')
ax1.set_yticklabels([])


vel_1_rms = df2['vel_1_rms'].values.T[0]

ax2.plot(df2['radius']/r_tot,df2['super_adiab']/0.0005,c='tab:brown')
ax2.plot(df2['radius']/r_tot,df2['flux_enthalpy']/1E10,c='tab:red')
ax2.plot(df2['radius']/r_tot,df2['flux_e_kin']/5E7,c='tab:blue')
ax2.plot(df2['radius']/r_tot,vel_1_rms/1E3,c='tab:olive')
ax2.set_yticklabels([])


vel_1_rms = df3['vel_1_rms'].values.T[0]

ax3.plot(df3['radius']/r_tot,df3['super_adiab']/0.0005,c='tab:brown')
ax3.plot(df3['radius']/r_tot,df3['flux_enthalpy']/1E10,c='tab:red')
ax3.plot(df3['radius']/r_tot,df3['flux_e_kin']/5E7,c='tab:blue')
ax3.plot(df3['radius']/r_tot,vel_1_rms/1E3,c='tab:olive')
ax3.set_yticklabels([])


fig.subplots_adjust(wspace=0, hspace=0)
ax3.set_xlabel('radius [r/R]')


ax1.grid()
ax2.grid()
ax3.grid()
    
ax1.set_title('Om0')

ax1.set_ylabel('Checkpoint ' + f1_name, rotation=45, labelpad=25)
ax2.set_ylabel('Checkpoint ' + f2_name, rotation=45, labelpad=25)
ax3.set_ylabel('Checkpoint ' + f3_name, rotation=45, labelpad=25)
fig.savefig('Om0_flux_plot.png')

# %%
df_OM0 = df1

# %%
df3['radius'][351] / r_tot # radius @ first super-adiabatic zero for df3
# Out:
# np.float64(0.7477182539700952)

# %%
PATTERN= "/z2/users/cj517/lscaledir_3D/r_min0.4_r_max0.9_from2d_v0_Om1/struc*"
all_files = sorted(glob.glob(PATTERN))

# %%
f1 = all_files[0]
f2 = all_files[148]
f3 = all_files[-1]

# %%
f1_name = f1[-4:]
f2_name = f2[-4:]
f3_name = f3[-4:]

# %%
df1 = pd.DataFrame(np.genfromtxt(f1,skip_header=3),columns=headers)
df1 = df1.set_index('index')
df2 = pd.DataFrame(np.genfromtxt(f2,skip_header=3),columns=headers)
df2 = df2.set_index('index')
df3 = pd.DataFrame(np.genfromtxt(f3,skip_header=3),columns=headers)
df3 = df3.set_index('index')

# %%
df1['super_adiab'] = df1['nabla'] - df1['nabla_adiab']
df2['super_adiab'] = df2['nabla'] - df2['nabla_adiab']
df3['super_adiab'] = df3['nabla'] - df3['nabla_adiab']

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3, sharex=True)
ax1.set_xlim(0.7, 0.76)
ax1.set_ylim(-2,1)
ax2.set_xlim(0.7, 0.76)
ax2.set_ylim(-2,1)
ax3.set_xlim(0.7, 0.76)
ax3.set_ylim(-2,1)

ax1.axhline(0, color='k',linewidth=1)
ax2.axhline(0, color='k',linewidth=1)
ax3.axhline(0, color='k',linewidth=1)

ax1.axvline(r_env_init / r_tot, color='k', label='Schw_1D',linewidth=2)
ax2.axvline(r_env_init / r_tot, color='k', label='Schw_1D',linewidth=2)
ax3.axvline(r_env_init / r_tot, color='k', label='Schw_1D',linewidth=2)


vel_1_rms = df1['vel_1_rms'].values.T[0]

ax1.plot(df1['radius']/r_tot,df1['super_adiab']/0.0005,c='tab:brown')
ax1.plot(df1['radius']/r_tot,df1['flux_enthalpy']/1E10,c='tab:red')
ax1.plot(df1['radius']/r_tot,df1['flux_e_kin']/5E7,c='tab:blue')
ax1.plot(df1['radius']/r_tot,vel_1_rms/1E3,c='tab:olive')
ax1.set_yticklabels([])


vel_1_rms = df2['vel_1_rms'].values.T[0]

ax2.plot(df2['radius']/r_tot,df2['super_adiab']/0.0005,c='tab:brown')
ax2.plot(df2['radius']/r_tot,df2['flux_enthalpy']/1E10,c='tab:red')
ax2.plot(df2['radius']/r_tot,df2['flux_e_kin']/5E7,c='tab:blue')
ax2.plot(df2['radius']/r_tot,vel_1_rms/1E3,c='tab:olive')
ax2.set_yticklabels([])


vel_1_rms = df3['vel_1_rms'].values.T[0]

ax3.plot(df3['radius']/r_tot,df3['super_adiab']/0.0005,c='tab:brown')
ax3.plot(df3['radius']/r_tot,df3['flux_enthalpy']/1E10,c='tab:red')
ax3.plot(df3['radius']/r_tot,df3['flux_e_kin']/5E7,c='tab:blue')
ax3.plot(df3['radius']/r_tot,vel_1_rms/1E3,c='tab:olive')
ax3.set_yticklabels([])


fig.subplots_adjust(wspace=0, hspace=0)
ax3.set_xlabel('radius [r/R]')


ax1.grid()
ax2.grid()
ax3.grid()
    
ax1.set_title('Om1')

ax1.set_ylabel('Checkpoint ' + f1_name, rotation=45, labelpad=25)
ax2.set_ylabel('Checkpoint ' + f2_name, rotation=45, labelpad=25)
ax3.set_ylabel('Checkpoint ' + f3_name, rotation=45, labelpad=25)
fig.savefig('Om1_flux_plot.png')

# %%
df_OM1 = df1

# %%
PATTERN= "/z2/users/cj517/lscaledir_3D/r_min0.4_r_max0.9_from2d_v0_Om5/struc*"
all_files = sorted(glob.glob(PATTERN))

# %%
f1 = all_files[0]
f2 = all_files[149]
f3 = all_files[-1]

# %%
f1_name = f1[-4:]
f2_name = f2[-4:]
f3_name = f3[-4:]

# %%
df1 = pd.DataFrame(np.genfromtxt(f1,skip_header=3),columns=headers)
df1 = df1.set_index('index')
df2 = pd.DataFrame(np.genfromtxt(f2,skip_header=3),columns=headers)
df2 = df2.set_index('index')
df3 = pd.DataFrame(np.genfromtxt(f3,skip_header=3),columns=headers)
df3 = df3.set_index('index')

# %%
df1['super_adiab'] = df1['nabla'] - df1['nabla_adiab']
df2['super_adiab'] = df2['nabla'] - df2['nabla_adiab']
df3['super_adiab'] = df3['nabla'] - df3['nabla_adiab']

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3, sharex=True)
ax1.set_xlim(0.7, 0.76)
ax1.set_ylim(-2,1)
ax2.set_xlim(0.7, 0.76)
ax2.set_ylim(-2,1)
ax3.set_xlim(0.7, 0.76)
ax3.set_ylim(-2,1)

ax1.axhline(0, color='k',linewidth=1)
ax2.axhline(0, color='k',linewidth=1)
ax3.axhline(0, color='k',linewidth=1)

ax1.axvline(r_env_init / r_tot, color='k', label='Schw_1D',linewidth=2)
ax2.axvline(r_env_init / r_tot, color='k', label='Schw_1D',linewidth=2)
ax3.axvline(r_env_init / r_tot, color='k', label='Schw_1D',linewidth=2)


vel_1_rms = df1['vel_1_rms'].values.T[0]

ax1.plot(df1['radius']/r_tot,df1['super_adiab']/0.0005,c='tab:brown')
ax1.plot(df1['radius']/r_tot,df1['flux_enthalpy']/2E9,c='tab:red')
ax1.plot(df1['radius']/r_tot,df1['flux_e_kin']/1E7,c='tab:blue')
ax1.plot(df1['radius']/r_tot,vel_1_rms/1E3,c='tab:olive')
ax1.set_yticklabels([])


vel_1_rms = df2['vel_1_rms'].values.T[0]

ax2.plot(df2['radius']/r_tot,df2['super_adiab']/0.0005,c='tab:brown')
ax2.plot(df2['radius']/r_tot,df2['flux_enthalpy']/2E9,c='tab:red')
ax2.plot(df2['radius']/r_tot,df2['flux_e_kin']/1E7,c='tab:blue')
ax2.plot(df2['radius']/r_tot,vel_1_rms/1E3,c='tab:olive')
ax2.set_yticklabels([])


vel_1_rms = df3['vel_1_rms'].values.T[0]

ax3.plot(df3['radius']/r_tot,df3['super_adiab']/0.0005,c='tab:brown')
ax3.plot(df3['radius']/r_tot,df3['flux_enthalpy']/2E9,c='tab:red')
ax3.plot(df3['radius']/r_tot,df3['flux_e_kin']/1E7,c='tab:blue')
ax3.plot(df3['radius']/r_tot,vel_1_rms/1E3,c='tab:olive')
ax3.set_yticklabels([])


fig.subplots_adjust(wspace=0, hspace=0)
ax3.set_xlabel('radius [r/R]')


ax1.grid()
ax2.grid()
ax3.grid()
    
ax1.set_title('Om5')

ax1.set_ylabel('Checkpoint ' + f1_name, rotation=45, labelpad=25)
ax2.set_ylabel('Checkpoint ' + f2_name, rotation=45, labelpad=25)
ax3.set_ylabel('Checkpoint ' + f3_name, rotation=45, labelpad=25)
fig.savefig('Om5_flux_plot.png')

# %%
df_OM5 = df1

# %%
f1_name = r'$\Omega=0$'
f2_name = r'$\Omega=1$'
f3_name = r'$\Omega=5$'

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3, sharex=True)
ax1.set_xlim(0.7, 0.76)
ax1.set_ylim(-2,1)
ax2.set_xlim(0.7, 0.76)
ax2.set_ylim(-2,1)
ax3.set_xlim(0.7, 0.76)
ax3.set_ylim(-2,1)

ax1.axhline(0, color='k',linewidth=1)
ax2.axhline(0, color='k',linewidth=1)
ax3.axhline(0, color='k',linewidth=1)

# Schwarzschild Criterion
ax1.axvline(r_env_init / r_tot, color='k', label='Schw_1D',linewidth=2)
ax2.axvline(r_env_init / r_tot, color='k', label='Schw_1D',linewidth=2)
ax3.axvline(r_env_init / r_tot, color='k', label='Schw_1D',linewidth=2)

# Mean Flux Depth
ax1.axvline(- 0.0027906596902863255 + r_env_init / r_tot, color='tab:blue', label='Schw_1D',linewidth=2)
ax2.axvline(- 0.0028516390372807718 + r_env_init / r_tot, color='tab:blue', label='Schw_1D',linewidth=2)
ax3.axvline(- 0.0030592407497879223 + r_env_init / r_tot, color='tab:blue', label='Schw_1D',linewidth=2)

# Mean Enthalpy Depth
ax1.axvline(- 0.0018626018388730712 + r_env_init / r_tot, color='tab:red', label='Schw_1D',linewidth=2)
ax2.axvline(- 0.00198720713513312 + r_env_init / r_tot, color='tab:red', label='Schw_1D',linewidth=2)
ax3.axvline(- 0.0023629231105871335 + r_env_init / r_tot, color='tab:red', label='Schw_1D',linewidth=2)

# Max Flux Depth
ax1.axvline(- 0.012841429568499827 + r_env_init / r_tot, color='tab:blue', label='Schw_1D',linewidth=2, linestyle=':')
ax2.axvline(- 0.012572467845509859 + r_env_init / r_tot, color='tab:blue', label='Schw_1D',linewidth=2, linestyle=':')
ax3.axvline(- 0.013418904363545814 + r_env_init / r_tot, color='tab:blue', label='Schw_1D',linewidth=2, linestyle=':')

# Max Enthalpy Depth
ax1.axvline(- 0.012841429568499827 + r_env_init / r_tot, color='tab:red', label='Schw_1D',linewidth=2, linestyle=':')
ax2.axvline(- 0.012572467845509859 + r_env_init / r_tot, color='tab:red', label='Schw_1D',linewidth=2, linestyle=':')
ax3.axvline(- 0.013418904363545814 + r_env_init / r_tot, color='tab:red', label='Schw_1D',linewidth=2, linestyle=':')


vel_1_rms = df_OM0['vel_1_rms'].values.T[0]

ax1.plot(df_OM0['radius']/r_tot,df_OM0['super_adiab']/0.0005,c='tab:brown')
ax1.plot(df_OM0['radius']/r_tot,df_OM0['flux_enthalpy']/1E10,c='tab:red')
ax1.plot(df_OM0['radius']/r_tot,df_OM0['flux_e_kin']/5E7,c='tab:blue')
ax1.plot(df_OM0['radius']/r_tot,vel_1_rms/1E3,c='tab:olive')
ax1.set_yticklabels([])


vel_1_rms = df_OM1['vel_1_rms'].values.T[0]

ax2.plot(df_OM1['radius']/r_tot,df_OM1['super_adiab']/0.0005,c='tab:brown')
ax2.plot(df_OM1['radius']/r_tot,df_OM1['flux_enthalpy']/1E10,c='tab:red')
ax2.plot(df_OM1['radius']/r_tot,df_OM1['flux_e_kin']/5E7,c='tab:blue')
ax2.plot(df_OM1['radius']/r_tot,vel_1_rms/1E3,c='tab:olive')
ax2.set_yticklabels([])


vel_1_rms = df_OM5['vel_1_rms'].values.T[0]

ax3.plot(df_OM5['radius']/r_tot,df_OM5['super_adiab']/0.0005,c='tab:brown')
ax3.plot(df_OM5['radius']/r_tot,df_OM5['flux_enthalpy']/2E9,c='tab:red')
ax3.plot(df_OM5['radius']/r_tot,df_OM5['flux_e_kin']/1E7,c='tab:blue')
ax3.plot(df_OM5['radius']/r_tot,vel_1_rms/1E3,c='tab:olive')
ax3.set_yticklabels([])


fig.subplots_adjust(wspace=0, hspace=0)
ax3.set_xlabel('radius [r/R]')


ax1.grid()
ax2.grid()
ax3.grid()
    
ax1.set_title('Typical profiles')

ax1.set_ylabel(f1_name) #, rotation=45, labelpad=25)
ax2.set_ylabel(f2_name) #, rotation=45, labelpad=25)
ax3.set_ylabel(f3_name) #, rotation=45, labelpad=25)
# Out:
# Text(0, 0.5, '$\\Omega=5$')
