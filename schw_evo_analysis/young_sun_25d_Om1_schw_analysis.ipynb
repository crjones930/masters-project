# %% [markdown]
# # Schwarzschild analysis
#
# From an initial look at the snapshots for the young_sun_2d it seems the Schwarzschild boundary is broken at the end.
# So I want to create plots of vorticity and temperature fluctuation to see if the boundary is clear there.

# %%
import cj_plotter
import os
from music_scripts.musicdata import MusicData
import glob
import numpy as np

# %%
# Simulation data

r_env_init = 4.147678716913737E+10
r_tot = 4.147678716913737E+10 / 0.44167

# %%
absolute_path = "/home/cj517/z1_data/r_min0.1_r_max0.97_25d/base_Om1/params.nml"
# absolute_path = "/home/cj517/my_z2/lscaledir_young_sun/r_min0.1_r_max0.97_2d/params_2D.nml"
PATTERN = os.path.relpath(absolute_path)

all_files = sorted(glob.glob(PATTERN))
all_files
# Out:
# ['../../z1_data/r_min0.1_r_max0.97_25d/base_Om1/params.nml']

# %%
sim = MusicData(PATTERN)

# %%
sim.__dict__
# Out:
# {'parfile': PosixPath('/z1/users/dv270/young_sun/r_min0.1_r_max0.97_25d/base_Om1/params.nml')}

# %%
r = sim[-1].grid.r_grid.cell_points()
t = sim[-1].grid.theta_grid.cell_points()

# %% [markdown]
# ## Radial velocity

# %%
vel_1 = sim[-1].field['vel_1'].array()

# %%
example_plot = cj_plotter.plot2D(t, r/r_tot, vel_1, -1e4, 1e4, cmap='RdBu') # , visible_ax=False)

example_plot.colorbar(label='vel_1')
example_plot.add_arc(r_env_init/r_tot, edgecolor='blue', label='1D_Schw')
example_plot.savefig('young_sun_Om1_vel_1.png')

# %% [markdown]
# ## Vorticity

# %%
vorticity = np.genfromtxt('young_sun_25d_Om1_vorticity.csv',delimiter=',').T

# %%
example_plot = cj_plotter.plot2D(t, r/r_tot, vorticity, -1e-5, 1e-5, cmap='RdBu') # , visible_ax=False)

example_plot.colorbar(label='vel_1')
example_plot.add_arc(r_env_init/r_tot, edgecolor='blue', label='1D_Schw')
example_plot.savefig('young_sun_Om1_vorticity.png')

# %% [markdown]
# ## Temperature fluctuations

# %%
from music_scripts.derived_fields import temp

# %%
T = temp(sim[-1])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 T = temp(sim[-1])
#
# File ~/miniconda3/envs/music/lib/python3.11/site-packages/music_scripts/derived_fields.py:222, in temp(bmdat)
#     219 @FieldGetter.register
#     220 def temp(bmdat: BaseMusicData) -> BigArray:
#     221     """Temperature."""
# --> 222     return bmdat.eos.temperature(bmdat.big_array)
#
# File ~/miniconda3/envs/music/lib/python3.11/site-packages/music_scripts/musicdata.py:58, in Snap.eos(self)
#      56 @property
#      57 def eos(self) -> eos.EoS:
# ---> 58     return self.mdat.eos
#
# File ~/miniconda3/envs/music/lib/python3.11/functools.py:1001, in cached_property.__get__(self, instance, owner)
#     999 val = cache.get(self.attrname, _NOT_FOUND)
#    1000 if val is _NOT_FOUND:
# -> 1001     val = self.func(instance)
#    1002     try:
#    1003         cache[self.attrname] = val
#
# File ~/miniconda3/envs/music/lib/python3.11/site-packages/music_scripts/musicdata.py:137, in MusicData.eos(self)
#     135 eos_name = self.params["microphysics"].get("eos", "mesa")
#     136 if eos_name == "mesa":
# --> 137     abd = self.params["abundances"]
#     138     metallicity = abd.get("metals_mass_fraction", 0.02)
#     139     he_scalar = abd.get("helium_scalar", 0)
#
# File ~/miniconda3/envs/music/lib/python3.11/site-packages/f90nml/namelist.py:181, in Namelist.__getitem__(self, key)
#     179         return Cogroup(self, lkey)
#     180     else:
# --> 181         return super(Namelist, self).__getitem__(lkey)
#     182 else:
#     183     keyiter = iter(key)
#
# KeyError: 'abundances'
